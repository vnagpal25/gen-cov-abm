# %%
import json
from collections import deque

# %%
with open('tree.json', 'r') as f:
    data = json.load(f)

# %%
tree = data['tree']

# %%
dates = []
q = deque([tree])
visited = set()
counter = 0
while q:
    # process node
    node = q.popleft()
    visited.add(node['name'])
    dates.append(node['node_attrs']['num_date']['value'])
    
    counter += 1

    children = []
    if 'children' in node:
        children = node['children']

    for child in children:
        if child['name'] in visited:
            continue
        q.append(child)        

print(f'Visited {counter} sequences')
# Out:
# Visited 14761 sequences

# %%
inferred_ancestors = [name for name in visited if "NODE" in name]
tip_sequences = [name for name in visited if "NODE" not in name]

print(f"{len(inferred_ancestors)} inferred ancestors")
print(inferred_ancestors[:5])

print(f"{len(tip_sequences)} observed tip sequences")
print(tip_sequences[:5])

ma_tip_seqs = [name for name in tip_sequences if "MA" in name]
len(ma_tip_seqs)
ma_tip_seqs[:10]
# Out:
# 6857 inferred ancestors
# ['NODE_0001554', 'NODE_0000614', 'NODE_0003751', 'NODE_0002535', 'NODE_0005090']
# 7904 observed tip sequences
# ['USA/VT-CDCBI-CRSP_D7JYQ57P6L5CF5N2/2021', 'USA/CA-CDC-FG-061174/2021', 'USA/FL-CDC-LC0079242/2021', 'USA/LA-BIE-LSUH001564/2021', 'USA/AK-PHL8497/2021']
# ['USA/MA-MGH-02755/2020',
#  'USA/MA-CDCBI-CRSP_EO6UB7QVIFTGPPBT/2021',
#  'USA/MA-CDCBI-CRSP_JDPMNSQ2IGW3VJKV/2021',
#  'USA/MA-CDCBI-CRSP_6M5SHLWBT6UY6V25/2021',
#  'USA/MA-MASPHL-04352/2021',
#  'USA/MA-CDCBI-CRSP_BAL2WINET3U2BMID/2021',
#  'USA/MA-CDCBI-CRSP_ANTIKQAA7FEX5JO5/2021',
#  'USA/MA-CDCBI-CRSP_NWLQJZWYX3X7N2GK/2021',
#  'USA/MA-CDCBI-CRSP_DQYSCJEXCTPFW46J/2021',
#  'USA/MA-CDC-STM-000034045/2021']
